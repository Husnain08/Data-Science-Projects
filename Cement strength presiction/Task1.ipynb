# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://ibm.box.com/shared/static/svl8tu7cmod6tizo6rk0ke4sbuhtpdfx.csv')
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
data_columns = data.columns

predictors = data[data_columns[data_columns != 'Strength']] # all columns except Strength
target = data['Strength'] # Strength column

# %% [markdown]
# # Normalizing the features

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(predictors_norm , target , test_size = 0.3)

# %%
n_cols = X_train.shape[1]
n_cols
# number of predictors
# Out:
# 8

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\user pc\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\user pc\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\user pc\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\user pc\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 10)                90
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# ...
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
for i in range(50):
    model.fit(X_train, y_train, batch_size = 300 , epochs= 100)
    print('')
    print ("Epoch  " + str(i) + "  is Completed  ")
    print('')
    y_pred=model.predict(X_test)
    error = mean_squared_error(y_pred,y_test)
    error_list = []
    error_list.append(error)
    print (error_list)
    error_mean = np.mean(error)
print('')
print ("The mean across all the errors is   " + str(np.mean(error_list)))
print('')
print ("The standard deviation across all the errors is  " + str(np.std(error_list)))
print('')
# Out:
# Epoch 1/100
# 721/721 [==============================] - 0s 12us/step - loss: 1222.1175
# Epoch 2/100
# 721/721 [==============================] - 0s 12us/step - loss: 1218.2139
# Epoch 3/100
# 721/721 [==============================] - 0s 10us/step - loss: 1214.2752
# Epoch 4/100
# 721/721 [==============================] - 0s 12us/step - loss: 1210.2328
# Epoch 5/100
# 721/721 [==============================] - 0s 12us/step - loss: 1206.2478
# Epoch 6/100
# 721/721 [==============================] - 0s 10us/step - loss: 1202.1751
# Epoch 7/100
# 721/721 [==============================] - 0s 11us/step - loss: 1198.1851
# Epoch 8/100
# 721/721 [==============================] - 0s 12us/step - loss: 1194.0404
# Epoch 9/100
# 721/721 [==============================] - 0s 10us/step - loss: 1190.0003
# Epoch 10/100
# 721/721 [==============================] - 0s 10us/step - loss: 1185.8597
# Epoch 11/100
# 721/721 [==============================] - 0s 11us/step - loss: 1181.7611
# ...

# %% [markdown]
# # Comparisons to other models

# %% [markdown]
# Model 1 results ( with no normalization and 50 epochs)
# The mean across all the errors is   236.39580469452875
#
# The standard deviation across all the errors is  605.4238709248465
#
# model 2 results ( with  normalization and 50 epochs)
# The mean across all the errors is   240.58395135518998
# The standard deviation across all the errors is  522.331982280129
#
# model 3 results ( with  normalization and 100 epochs)
# The mean across all the errors is   240.58395135518998
# The standard deviation across all the errors is  522.331982280129
