# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('concrete_data.csv')
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
data_columns = data.columns

predictors = data[data_columns[data_columns != 'Strength']] # all columns except Strength
target = data['Strength'] # Strength column

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(predictors_norm , target , test_size = 0.3)

# %%
n_cols = X_train.shape[1]
n_cols
# number of predictors
# Out:
# 8

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 10)                90
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# ...
# Total params: 321
# Trainable params: 321
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
error_list = []
for i in range(50):
    model.fit(X_train, y_train, batch_size = 300 , epochs= 50)
    print('')
    print ("Epoch  " + str(i) + "  is Completed  ")
    print('')
    y_pred=model.predict(X_test)
    error = mean_squared_error(y_pred,y_test)
    error_list.append(error)
    print (error_list)
    error_mean = np.mean(error)
print('')
print ("The mean across all the errors is   " + str(np.mean(error_list)))
print('')
print ("The standard deviation across all the errors is  " + str(np.std(error_list)))
print('')
# Out:
# Epoch 1/50
# 721/721 [==============================] - 0s 7us/step - loss: 17.4720
# Epoch 2/50
# 721/721 [==============================] - 0s 7us/step - loss: 17.4591
# Epoch 3/50
# 721/721 [==============================] - 0s 7us/step - loss: 17.4724
# Epoch 4/50
# 721/721 [==============================] - 0s 7us/step - loss: 17.4801
# Epoch 5/50
# 721/721 [==============================] - 0s 7us/step - loss: 17.4600
# Epoch 6/50
# 721/721 [==============================] - 0s 7us/step - loss: 17.4774
# Epoch 7/50
# 721/721 [==============================] - 0s 7us/step - loss: 17.5014
# Epoch 8/50
# 721/721 [==============================] - 0s 7us/step - loss: 17.6043
# Epoch 9/50
# 721/721 [==============================] - 0s 30us/step - loss: 17.4455
# Epoch 10/50
# 721/721 [==============================] - 0s 25us/step - loss: 17.4742
# Epoch 11/50
# 721/721 [==============================] - 0s 18us/step - loss: 17.4597
# Epoch 12/50
# ...

# %% [markdown]
# # Part D Results
# # With Increased number of hidden layers with normalization across 50 epochs

# %% [markdown]
# The mean across all the errors is   36.20446336466371
#
#
#
# The standard deviation across all the errors is  0.3428488321268328

# %% [markdown]
# # Comparsion

# %% [markdown]
# The mean error and standard deviation between error decreases significantly with increased number of hidden layers across 50 epochs

# %% [markdown]
# # Part C Results
# # Feature Normalization and 100 epochs

# %% [markdown]
# The mean across all the errors is   151.63114878744253
#
# The standard deviation across all the errors is  279.20597793171385

# %% [markdown]
# # Part B Results With Feature Normalization
# # Mean average and variance of Error across 50 epochs

# %% [markdown]
# The mean across all the errors is   218.526447647379
#
# The standard deviation across all the errors is  301.3355291928917

# %% [markdown]
# # Result of Part A ( No normalization across 50 epochs)

# %% [markdown]
# The Part A results were as follows:
#
# The mean across all the errors was 94.38386450526025
# The standard deviation across all the errors was 22.658978999251133
